# %%
from pathlib import Path
import pandas as pd

# %%
current_dir = Path.cwd()
parent_dir = current_dir.parent
data_dir = Path.cwd().parent / "datasets"
file_path = data_dir / "food_consumption.csv"
file_path2 = Path.cwd().parent / "datasets" / "food_consumption.csv"

# %%
print(current_dir)
type(current_dir)

print(parent_dir)
print(data_dir)
print(file_path)
print(file_path2)
# Out:
# c:\Users\ondre\Desktop\git\github (not a repo)\python (not a repo)\python_useful_stuff
# c:\Users\ondre\Desktop\git\github (not a repo)\python (not a repo)
# c:\Users\ondre\Desktop\git\github (not a repo)\python (not a repo)\datasets
# c:\Users\ondre\Desktop\git\github (not a repo)\python (not a repo)\datasets\food_consumption.csv
# c:\Users\ondre\Desktop\git\github (not a repo)\python (not a repo)\datasets\food_consumption.csv

# %%
food_consumption = pd.read_csv(file_path)
