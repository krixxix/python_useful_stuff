# %% [markdown]
# # Zip
# - we have 2 lists with corresponding values

# %%
names = ["Alice", "Bob", "Charlie", "David"]
ages = [30,25,35,20]

# %% [markdown]
# #### Without the zip() function

# %%
for idx in range(len(names)):  
    name = names[idx]
    age = ages[idx]
    print(f"{name} is {age} years old")
# Out:
# Alice is 30 years old
# Bob is 25 years old
# Charlie is 35 years old
# David is 20 years old

# %% [markdown]
# #### Using the zip() function

# %%
combined = list(zip(names,ages))

for name,age in combined:
    print(f"{name} is {age} years old.")

print(combined)
# Out:
# Alice is 30 years old.
# Bob is 25 years old.
# Charlie is 35 years old.
# David is 20 years old.
# [('Alice', 30), ('Bob', 25), ('Charlie', 35), ('David', 20)]

# %% [markdown]
# #### Even more lists

# %%
names = ["Alice", "Bob", "Charlie", "David"]
ages = [30,25,35,20]
gender = ["Female","Male","Male"] # I have less values: zip will solve it for me

combined2 = zip(names,ages,gender)

for name,age,gender in combined2:
    print(f"{name} is {gender} and is {age} years old.")
# Out:
# Alice is Female and is 30 years old.
# Bob is Male and is 25 years old.
# Charlie is Male and is 35 years old.
